# %% [markdown]
# # Checkpoint 1: Multi-Agent Reinforcement Learning Experiments
#
# Independent Q-learning VS Cooperative Q-learning

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from collections import deque
import time
import random
import math
from collections import defaultdict

SEED = 42
np.random.seed(SEED)
random.seed(SEED)

try:
    import gymnasium as gym
    from gymnasium import spaces
except ImportError:
    import gym  
    from gym import spaces

# %%
class WarehouseConfig:
    def __init__(self):
        self.grid_size = (6, 6)
        self.start_pos = None
        self.pickup_pos = (0, 5)
        self.dropoff_pos = (5, 0)
        self.obstacles = set([
            (1, 1), (1, 2), (1, 3), 
            (3, 1), (3, 2), (3, 3),  
            (4, 4), (5, 4)           
        ])
        # reward
        self.step_penalty = -0.8  # penalty
        self.obstacle_penalty = -15.0  # penalty for obstacle
        self.first_pick_reward = 35.0  
        self.delivery_reward = 200.0  
        self.render_mode = "matplotlib"


class WarehouseBase(gym.Env):
    """warehouse setup"""
    
    def __init__(self, config=None, seed=None):
        gym.Env.__init__(self)
        if config is None:
            config = WarehouseConfig()
        self.cfg = config
        self.rows, self.cols = self.cfg.grid_size
        self.obstacles = set(self.cfg.obstacles)
        self.pickup = self.cfg.pickup_pos
        self.dropoff = self.cfg.dropoff_pos
        self.observation_space = spaces.MultiDiscrete([self.rows, self.cols, 2])
        self.action_space = spaces.Discrete(6)
        self.rng = np.random.default_rng(seed)
        self.state = (0, 0)
        self.carrying = False
        self.picked_once = False
        self.delivered = False
        self.total_steps = 0
        self.total_reward = 0.0

    def get_valid_start_positions(self):
        valid_positions = []
        for r in range(self.rows):
            for c in range(self.cols):
                pos = (r, c)
                if (pos not in self.obstacles and 
                    pos != self.pickup and 
                    pos != self.dropoff):
                    valid_positions.append(pos)
        return valid_positions

    def move(self, action):
        UP, DOWN, LEFT, RIGHT, PICK, DROP = 0, 1, 2, 3, 4, 5
        r, c = self.state
        if action == UP:
            return (max(0, r - 1), c)
        elif action == DOWN:
            return (min(self.rows - 1, r + 1), c)
        elif action == LEFT:
            return (r, max(0, c - 1))
        elif action == RIGHT:
            return (r, min(self.cols - 1, c + 1))
        return self.state

    def apply_move_with_collisions(self, target_position):
        if target_position in self.obstacles:
            return self.state, self.cfg.obstacle_penalty
        return (target_position, 0.0)

    def handle_pickup(self):
        if isinstance(self.state, tuple):
            robot_position = self.state
        else:
            robot_position = tuple(self.state)
        if robot_position != self.pickup:
            return 0.0
        if self.carrying:
            return 0.0
        self.carrying = True
        if not self.picked_once:
            self.picked_once = True
            return self.cfg.first_pick_reward
        return 0.0

    def handle_dropoff(self):
        if isinstance(self.state, tuple):
            robot_position = self.state
        else:
            robot_position = tuple(self.state)
        if not self.carrying:
            return (0.0, False)
        if robot_position != self.dropoff:
            return (0.0, False)
        self.carrying = False
        self.delivered = True
        return (self.cfg.delivery_reward, True)

    def reset(self, seed=None, options=None):
        gym.Env.reset(self, seed=seed)
        if seed is not None:
            self.rng = np.random.default_rng(seed)
        valid_positions = self.get_valid_start_positions()
        if valid_positions:
            self.state = tuple(self.rng.choice(valid_positions))
        else:
            self.state = (0, 0)
        self.carrying = False
        self.picked_once = False
        self.delivered = False
        self.total_steps = 0
        self.total_reward = 0.0
        obs = np.array([self.state[0], self.state[1], int(self.carrying)], dtype=np.int64)
        return obs, {"position": self.state, "carrying": self.carrying}

    def step(self, action):
        UP, DOWN, LEFT, RIGHT, PICK, DROP = 0, 1, 2, 3, 4, 5
        step_reward = self.cfg.step_penalty
        game_ended = False
        game_truncated = False
        if action in (UP, DOWN, LEFT, RIGHT):
            target_position = self.move(action)
            actual_position, collision_penalty = self.apply_move_with_collisions(target_position)
            self.state = actual_position
            step_reward += collision_penalty
        elif action == PICK:
            pickup_reward = self.handle_pickup()
            step_reward += pickup_reward
        elif action == DROP:
            dropoff_reward, completed = self.handle_dropoff()
            step_reward += dropoff_reward
            if completed:
                game_ended = True
        self.total_steps += 1
        self.total_reward += step_reward
        if self.total_steps >= 200:
            game_truncated = True
        obs = np.array([self.state[0], self.state[1], int(self.carrying)], dtype=np.int64)
        info = {
            "position": self.state,
            "carrying": self.carrying,
            "delivered": self.delivered,
            "total_steps": self.total_steps
        }
        return obs, step_reward, game_ended, game_truncated, info

    def render(self):
        pass

    def close(self):
        pass


class WarehouseRobotDetEnv(WarehouseBase):
    pass

# %%
class MultiAgentWarehouseEnv(gym.Env):
    
    def __init__(self, base_env_class, config=None, num_agents=2, seed=None):
        gym.Env.__init__(self)
        self.num_agents = num_agents
        self.base_env_class = base_env_class
        if config is None:
            config = WarehouseConfig()
        self.cfg = config
        self.rows, self.cols = self.cfg.grid_size
        self.obstacles = set(self.cfg.obstacles)
        self.pickup = self.cfg.pickup_pos
        self.dropoff = self.cfg.dropoff_pos
        self.rng = np.random.default_rng(seed)

        # for each agent create a separate environment
        self.agent_envs = []
        for i in range(num_agents):
            env = base_env_class(config=config, seed=seed)
            self.agent_envs.append(env)
        self.observation_space = spaces.Tuple([
            spaces.MultiDiscrete([self.rows, self.cols, 2]) 
            for _ in range(num_agents)
        ])
        self.action_space = spaces.Tuple([
            spaces.Discrete(6) for _ in range(num_agents)
        ])

        # initialize every agent states
        self.agent_states = [(0, 0) for _ in range(num_agents)]
        self.agent_carrying = [False for _ in range(num_agents)]
        self.agent_picked_once = [False for _ in range(num_agents)]
        self.agent_delivered = [False for _ in range(num_agents)]
        self.total_steps = 0
        
    def get_valid_start_positions(self):
        valid_positions = []
        for r in range(self.rows):
            for c in range(self.cols):
                pos = (r, c)
                if (pos not in self.obstacles and 
                    pos != self.pickup and 
                    pos != self.dropoff):
                    valid_positions.append(pos)
        return valid_positions
    
    def reset(self, seed=None, options=None):
        gym.Env.reset(self, seed=seed)
        if seed is not None:
            self.rng = np.random.default_rng(seed)
        observations = []
        for i, env in enumerate(self.agent_envs):
            obs, info = env.reset(seed=seed)
            # position is tuple type
            pos_tuple = tuple(obs[:2])
            self.agent_states[i] = pos_tuple
            self.agent_carrying[i] = bool(obs[2])
            self.agent_picked_once[i] = False
            self.agent_delivered[i] = False
            observations.append(obs)

            
        self._resolve_start_position_conflicts()
        observations = []
        for i in range(self.num_agents):
            # agent_states[i] is tuple too
            pos = self.agent_states[i]
            if isinstance(pos, np.ndarray):
                pos = tuple(pos)
            elif not isinstance(pos, tuple):
                pos = tuple(pos)
            self.agent_states[i] = pos
            
            obs = np.array([
                pos[0],
                pos[1],
                int(self.agent_carrying[i])
            ], dtype=np.int64)
            observations.append(obs)
        self.total_steps = 0
        info = {
            "agent_positions": [self.agent_states[i] for i in range(self.num_agents)],
            "agent_carrying": [self.agent_carrying[i] for i in range(self.num_agents)],
            "agent_delivered": [self.agent_delivered[i] for i in range(self.num_agents)]
        }
        return tuple(observations), info
    
    def _resolve_start_position_conflicts(self):
        used_positions = set()
        valid_positions = self.get_valid_start_positions()
        for i in range(self.num_agents):
            current_pos = self.agent_states[i]
            if isinstance(current_pos, np.ndarray):
                current_pos = tuple(current_pos)
            elif not isinstance(current_pos, tuple):
                current_pos = tuple(current_pos)
            
            if current_pos in used_positions:
                available = [p for p in valid_positions if p not in used_positions]
                if available:
                    new_pos = self.rng.choice(available)
    
                    if isinstance(new_pos, np.ndarray):
                        new_pos = tuple(new_pos)
                    elif not isinstance(new_pos, tuple):
                        new_pos = tuple(new_pos)
                    self.agent_states[i] = new_pos
                    self.agent_envs[i].state = new_pos
                    current_pos = new_pos  
            
            
            if isinstance(current_pos, np.ndarray):
                current_pos = tuple(current_pos)
            elif not isinstance(current_pos, tuple):
                current_pos = tuple(current_pos)
            
            used_positions.add(current_pos)
    
    def _handle_agent_collisions(self, proposed_positions):
        final_positions = list(proposed_positions)
        position_counts = {}
        for i, pos in enumerate(final_positions):
            pos_tuple = tuple(pos)
            if pos_tuple not in position_counts:
                position_counts[pos_tuple] = []
            position_counts[pos_tuple].append(i)
        for pos_tuple, agent_indices in position_counts.items():
            if len(agent_indices) > 1:
                for agent_idx in agent_indices:
                    final_positions[agent_idx] = self.agent_states[agent_idx]
        return final_positions
    
    def step(self, actions):
        UP, DOWN, LEFT, RIGHT, PICK, DROP = 0, 1, 2, 3, 4, 5
        
        def clamp(value, min_val, max_val):
            return max(min_val, min(value, max_val))
        
        self.total_steps += 1
        individual_rewards = []
        proposed_positions = []
        for i, action in enumerate(actions):
            reward = self.cfg.step_penalty
            if action in (UP, DOWN, LEFT, RIGHT):
                r, c = self.agent_states[i]
                if action == UP:
                    r -= 1
                elif action == DOWN:
                    r += 1
                elif action == LEFT:
                    c -= 1
                elif action == RIGHT:
                    c += 1
                r = clamp(r, 0, self.rows - 1)
                c = clamp(c, 0, self.cols - 1)
                proposed_pos = (r, c)
                if proposed_pos in self.obstacles:
                    reward += self.cfg.obstacle_penalty
                    proposed_pos = self.agent_states[i]
                proposed_positions.append(proposed_pos)
                individual_rewards.append(reward)
            else:
                proposed_positions.append(self.agent_states[i])
                individual_rewards.append(self.cfg.step_penalty)
        final_positions = self._handle_agent_collisions(proposed_positions)
        for i, action in enumerate(actions):
            self.agent_states[i] = final_positions[i]
            self.agent_envs[i].state = final_positions[i]
            if action == PICK:
                reward = self._handle_pickup(i)
                individual_rewards[i] += reward
            elif action == DROP:
                reward, is_completed = self._handle_dropoff(i)
                individual_rewards[i] += reward
                if is_completed:
                    self.agent_delivered[i] = True
        all_delivered = all(self.agent_delivered)
        terminated = all_delivered
        observations = []
        for i in range(self.num_agents):
            obs = np.array([
                self.agent_states[i][0],
                self.agent_states[i][1],
                int(self.agent_carrying[i])
            ], dtype=np.int64)
            observations.append(obs)
        team_reward = sum(individual_rewards)
        info = {
            "individual_rewards": individual_rewards,
            "team_reward": team_reward,
            "agent_positions": [self.agent_states[i] for i in range(self.num_agents)],
            "agent_carrying": [self.agent_carrying[i] for i in range(self.num_agents)],
            "agent_delivered": [self.agent_delivered[i] for i in range(self.num_agents)],
            "total_steps": self.total_steps
        }
        return (
            tuple(observations),
            individual_rewards,
            terminated,
            False,
            info
        )
    
    def _handle_pickup(self, agent_idx):
        agent_pos = self.agent_states[agent_idx]
        if agent_pos != self.pickup:
            return 0.0
        if self.agent_carrying[agent_idx]:
            return 0.0
        self.agent_carrying[agent_idx] = True
        self.agent_envs[agent_idx].carrying = True
        if not self.agent_picked_once[agent_idx]:
            self.agent_picked_once[agent_idx] = True
            return self.cfg.first_pick_reward
        return 0.0
    
    def _handle_dropoff(self, agent_idx):
        agent_pos = self.agent_states[agent_idx]
        if not self.agent_carrying[agent_idx]:
            return (0.0, False)
        if agent_pos != self.dropoff:
            return (0.0, False)
        self.agent_carrying[agent_idx] = False
        self.agent_envs[agent_idx].carrying = False
        self.agent_delivered[agent_idx] = True
        return (self.cfg.delivery_reward, True)
    
    def close(self):
        for env in self.agent_envs:
            env.close()

# %%
class IndependentQLearning:
    """no share qtable"""
    
    def __init__(self, num_agents, state_space_size, action_space_size, 
                 learning_rate=0.1, discount_factor=0.95, epsilon_start=1.0, 
                 epsilon_end=0.1, epsilon_decay=0.995, seed=42):
        self.num_agents = num_agents
        self.state_space_size = state_space_size
        self.action_space_size = action_space_size
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.epsilon = epsilon_start
        self.epsilon_start = epsilon_start
        self.epsilon_end = epsilon_end
        self.epsilon_decay = epsilon_decay
        self.rng = np.random.default_rng(seed)
        self.random_state = random.getstate()
        random.seed(seed)
        self.q_tables = [defaultdict(lambda: np.zeros(action_space_size)) 
                         for _ in range(num_agents)]
        self.episode_rewards = [[] for _ in range(num_agents)]
        self.total_updates = [0 for _ in range(num_agents)]
    
    def state_to_key(self, state):
        return tuple(state.astype(int))
    
    def select_action(self, agent_idx, state, training=True):
        state_key = self.state_to_key(state)
        if training and self.rng.random() < self.epsilon:
            return self.rng.integers(0, self.action_space_size)
        else:
            q_values = self.q_tables[agent_idx][state_key]
            max_q = np.max(q_values)
            best_actions = np.where(q_values == max_q)[0]
            return int(self.rng.choice(best_actions))
    
    def update(self, agent_idx, state, action, reward, next_state, done):
        state_key = self.state_to_key(state)
        next_state_key = self.state_to_key(next_state)
        current_q = self.q_tables[agent_idx][state_key][action]
        if done:
            target_q = reward
        else:
            next_max_q = np.max(self.q_tables[agent_idx][next_state_key])
            target_q = reward + self.discount_factor * next_max_q
        new_q = current_q + self.learning_rate * (target_q - current_q)
        self.q_tables[agent_idx][state_key][action] = new_q
        self.total_updates[agent_idx] += 1
    
    def decay_epsilon(self, episode):
        self.epsilon = max(self.epsilon_end, 
                          self.epsilon_start * math.exp(-self.epsilon_decay * episode))
    
    def get_policy(self, agent_idx, state):
        state_key = self.state_to_key(state)
        q_values = self.q_tables[agent_idx][state_key]
        return int(np.argmax(q_values))

# %%
class CooperativeQLearning:
    
    def __init__(self, num_agents, state_space_size, action_space_size,
                 learning_rate=0.1, discount_factor=0.95, epsilon_start=1.0,
                 epsilon_end=0.1, epsilon_decay=0.995, seed=42):
        self.num_agents = num_agents
        self.state_space_size = state_space_size
        self.action_space_size = action_space_size
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.epsilon = epsilon_start
        self.epsilon_start = epsilon_start
        self.epsilon_end = epsilon_end
        self.epsilon_decay = epsilon_decay
        self.rng = np.random.default_rng(seed)
        self.joint_action_space_size = action_space_size ** num_agents
        self.q_table = defaultdict(lambda: np.zeros(self.joint_action_space_size))
        self.episode_rewards = []
        self.total_updates = 0
    
    def joint_state_to_key(self, joint_state):
        state_tuples = tuple(tuple(s.astype(int)) for s in joint_state)
        return state_tuples
    
    def joint_action_to_index(self, joint_action):
        index = 0
        for i, action in enumerate(joint_action):
            index += action * (self.action_space_size ** (self.num_agents - 1 - i))
        return index
    
    def index_to_joint_action(self, index):
        joint_action = []
        remaining = index
        for i in range(self.num_agents):
            power = self.action_space_size ** (self.num_agents - 1 - i)
            action = remaining // power
            remaining = remaining % power
            joint_action.append(action)
        return tuple(joint_action)
    
    def select_joint_action(self, joint_state, training=True):
        joint_state_key = self.joint_state_to_key(joint_state)
        if training and self.rng.random() < self.epsilon:
            joint_action = tuple(self.rng.integers(0, self.action_space_size) 
                                for _ in range(self.num_agents))
        else:
            q_values = self.q_table[joint_state_key]
            max_q = np.max(q_values)
            best_indices = np.where(q_values == max_q)[0]
            best_index = int(self.rng.choice(best_indices))
            joint_action = self.index_to_joint_action(best_index)
        return joint_action
    
    def update(self, joint_state, joint_action, team_reward, next_joint_state, done):
        joint_state_key = self.joint_state_to_key(joint_state)
        next_joint_state_key = self.joint_state_to_key(next_joint_state)
        joint_action_idx = self.joint_action_to_index(joint_action)
        current_q = self.q_table[joint_state_key][joint_action_idx]
        if done:
            target_q = team_reward
        else:
            next_max_q = np.max(self.q_table[next_joint_state_key])
            target_q = team_reward + self.discount_factor * next_max_q
        new_q = current_q + self.learning_rate * (target_q - current_q)
        self.q_table[joint_state_key][joint_action_idx] = new_q
        self.total_updates += 1
    
    def decay_epsilon(self, episode):
        self.epsilon = max(self.epsilon_end, 
                          self.epsilon_start * math.exp(-self.epsilon_decay * episode))
    
    def get_policy(self, joint_state):
        joint_state_key = self.joint_state_to_key(joint_state)
        q_values = self.q_table[joint_state_key]
        best_index = int(np.argmax(q_values))
        return self.index_to_joint_action(best_index)

# %%
def train_independent_qlearning(env, num_episodes=5000, max_steps_per_episode=200,
                                learning_rate=0.1, discount_factor=0.95,
                                epsilon_start=1.0, epsilon_end=0.1, epsilon_decay=0.995, seed=42):
    num_agents = env.num_agents
    state_space_size = (env.rows, env.cols, 2)
    action_space_size = 6
    
    agent = IndependentQLearning(
        num_agents=num_agents,
        state_space_size=state_space_size,
        action_space_size=action_space_size,
        learning_rate=learning_rate,
        discount_factor=discount_factor,
        epsilon_start=epsilon_start,
        epsilon_end=epsilon_end,
        epsilon_decay=epsilon_decay
    )
    
    episode_rewards = [] 
    episode_epsilons = [] 
    episode_lengths = []
    episode_success = []
    recent_rewards = deque(maxlen=100)
    
    print("Training Independent Q-Learning...")
    print(f"Total episodes: {num_episodes}")
    
    for episode in range(num_episodes):
        episode_seed = seed + episode if seed is not None else None
        observations, info = env.reset(seed=episode_seed)
        episode_reward = [0.0 for _ in range(num_agents)]
        episode_length = 0
        done = False
        
        while not done and episode_length < max_steps_per_episode:
            actions = []
            for i in range(num_agents):
                action = agent.select_action(i, observations[i], training=True)
                actions.append(action)
            
            next_observations, rewards, terminated, truncated, info = env.step(tuple(actions))
            done = terminated or truncated
            
            for i in range(num_agents):
                agent.update(
                    agent_idx=i,
                    state=observations[i],
                    action=actions[i],
                    reward=rewards[i],
                    next_state=next_observations[i],
                    done=done
                )
                episode_reward[i] += rewards[i]
            
            observations = next_observations
            episode_length += 1
        
        total_episode_reward = sum(episode_reward)
        episode_rewards.append(total_episode_reward)
        episode_lengths.append(episode_length)
        recent_rewards.append(total_episode_reward)
        success = all(info['agent_delivered'])
        episode_success.append(1 if success else 0)
        agent.decay_epsilon(episode) 
        episode_epsilons.append(agent.epsilon)  
        
        if (episode + 1) % 100 == 0:
            avg_reward = np.mean(recent_rewards)
            success_rate = np.mean(episode_success[-100:])
            print(f"Episode {episode + 1}/{num_episodes} | "
                  f"Avg Reward: {avg_reward:.2f} | "
                  f"Success Rate: {success_rate:.2%} | "
                  f"Epsilon: {agent.epsilon:.3f}")
    
    training_history = {
        'episode_rewards': episode_rewards,
        'episode_lengths': episode_lengths,
        'episode_success': episode_success,
        'episode_epsilons': episode_epsilons,  
        'num_episodes': num_episodes
    }
    
    return training_history, agent

# %%
def train_cooperative_qlearning(env, num_episodes=2000, max_steps_per_episode=200,
                                learning_rate=0.12, discount_factor=0.95,
                                epsilon_start=1.0, epsilon_end=0.1, epsilon_decay=0.995, seed=42):
    num_agents = env.num_agents
    state_space_size = (env.rows, env.cols, 2)
    action_space_size = 6
    
    agent = CooperativeQLearning(
        num_agents=num_agents,
        state_space_size=state_space_size,
        action_space_size=action_space_size,
        learning_rate=learning_rate,
        discount_factor=discount_factor,
        epsilon_start=epsilon_start,
        epsilon_end=epsilon_end,
        epsilon_decay=epsilon_decay,
        seed=seed
    )
    
    episode_rewards = []
    episode_epsilons = [] 
    episode_lengths = []
    episode_success = []
    recent_rewards = deque(maxlen=100)
    
    print("Training Cooperative Q-Learning...")
    print(f"Total episodes: {num_episodes}")
    
    for episode in range(num_episodes):
        episode_seed = seed + episode if seed is not None else None
        observations, info = env.reset(seed=episode_seed)
        episode_reward = 0.0
        episode_length = 0
        done = False
        
        while not done and episode_length < max_steps_per_episode:
            joint_action = agent.select_joint_action(observations, training=True)
            next_observations, rewards, terminated, truncated, info = env.step(joint_action)
            done = terminated or truncated
            team_reward = sum(rewards)
            if done:  
                if all(info['agent_delivered']):
                    team_success_bonus = 500.0  
                    team_reward += team_success_bonus
                else:
                    partial_failure_penalty = -200.0 
                    team_reward += partial_failure_penalty
            
            episode_reward += team_reward
            
            agent.update(
                joint_state=observations,
                joint_action=joint_action,
                team_reward=team_reward,
                next_joint_state=next_observations,
                done=done
            )
            
            observations = next_observations
            episode_length += 1
        
        episode_rewards.append(episode_reward)
        episode_lengths.append(episode_length)
        recent_rewards.append(episode_reward)
        success = all(info['agent_delivered'])
        episode_success.append(1 if success else 0)
        agent.decay_epsilon(episode) 
        episode_epsilons.append(agent.epsilon)  
        
        if (episode + 1) % 100 == 0:
            avg_reward = np.mean(recent_rewards)
            success_rate = np.mean(episode_success[-100:])
            print(f"Episode {episode + 1}/{num_episodes} | "
                  f"Avg Reward: {avg_reward:.2f} | "
                  f"Success Rate: {success_rate:.2%} | "
                  f"Epsilon: {agent.epsilon:.3f}")
    
    training_history = {
        'episode_rewards': episode_rewards,
        'episode_lengths': episode_lengths,
        'episode_success': episode_success,
        'episode_epsilons': episode_epsilons,  
        'num_episodes': num_episodes
    }
    
    return training_history, agent

# %%
def evaluate_agent(env, agent, method='independent', num_episodes=100, max_steps=200, seed=None):
    
    episode_rewards = []
    episode_lengths = []
    episode_success = []
    
    print(f"\nEvaluating {method} agent...")
    
    
    for episode in range(num_episodes):
        if seed is not None:
            episode_seed = seed + episode 
        else:
            episode_seed = None
        observations, info = env.reset(seed=episode_seed)
        episode_reward = 0.0
        episode_length = 0
        done = False
        
        while not done and episode_length < max_steps:
            if method == 'independent':
                actions = []
                for i in range(env.num_agents):
                    action = agent.select_action(i, observations[i], training=False)
                    actions.append(action)
                actions = tuple(actions)
            else:
                joint_action = agent.select_joint_action(observations, training=False)
                actions = joint_action
            
            next_observations, rewards, terminated, truncated, info = env.step(actions)
            done = terminated or truncated
            episode_reward += sum(rewards)
            observations = next_observations
            episode_length += 1
        
        episode_rewards.append(episode_reward)
        episode_lengths.append(episode_length)
        success = all(info['agent_delivered'])
        episode_success.append(1 if success else 0)
    
    evaluation_results = {
        'episode_rewards': episode_rewards,
        'episode_lengths': episode_lengths,
        'episode_success': episode_success,
        'mean_reward': np.mean(episode_rewards),
        'std_reward': np.std(episode_rewards),
        'mean_length': np.mean(episode_lengths),
        'std_length': np.std(episode_lengths),
        'success_rate': np.mean(episode_success)
    }
    
    print(f"Mean Reward: {evaluation_results['mean_reward']:.2f} ± {evaluation_results['std_reward']:.2f}")
    print(f"Mean Length: {evaluation_results['mean_length']:.2f} ± {evaluation_results['std_length']:.2f}")
    print(f"Success Rate: {evaluation_results['success_rate']:.2%}")
    
    return evaluation_results

# %%
def plot_training_curves(history_iql, history_cql, save_path='results'):
   
    os.makedirs(save_path, exist_ok=True)
    
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    ax = axes[0, 0]
    window = 50
    if len(history_iql['episode_rewards']) >= window:
        smoothed_iql = np.convolve(history_iql['episode_rewards'], 
                                   np.ones(window)/window, mode='valid')
        smoothed_cql = np.convolve(history_cql['episode_rewards'],
                                   np.ones(window)/window, mode='valid')
        ax.plot(smoothed_iql, label='Independent Q-Learning', alpha=0.7)
        ax.plot(smoothed_cql, label='Cooperative Q-Learning', alpha=0.7)
    else:
        ax.plot(history_iql['episode_rewards'], 
               label='Independent Q-Learning', alpha=0.7)
        ax.plot(history_cql['episode_rewards'],
               label='Cooperative Q-Learning', alpha=0.7)
    
    ax.set_xlabel('Episode')
    ax.set_ylabel('Total Reward')
    ax.set_title('Training: Episode Rewards')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    ax = axes[0, 1]
    if len(history_iql['episode_success']) >= window:
        success_iql = np.convolve(history_iql['episode_success'],
                                 np.ones(window)/window, mode='valid')
        success_cql = np.convolve(history_cql['episode_success'],
                                 np.ones(window)/window, mode='valid')
        ax.plot(success_iql, label='Independent Q-Learning', alpha=0.7)
        ax.plot(success_cql, label='Cooperative Q-Learning', alpha=0.7)
    else:
        ax.plot(history_iql['episode_success'],
               label='Independent Q-Learning', alpha=0.7)
        ax.plot(history_cql['episode_success'],
               label='Cooperative Q-Learning', alpha=0.7)
    
    ax.set_xlabel('Episode')
    ax.set_ylabel('Success Rate')
    ax.set_title('Training: Success Rate')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    ax = axes[1, 0]
    if len(history_iql['episode_lengths']) >= window:
        length_iql = np.convolve(history_iql['episode_lengths'],
                                np.ones(window)/window, mode='valid')
        length_cql = np.convolve(history_cql['episode_lengths'],
                                np.ones(window)/window, mode='valid')
        ax.plot(length_iql, label='Independent Q-Learning', alpha=0.7)
        ax.plot(length_cql, label='Cooperative Q-Learning', alpha=0.7)
    else:
        ax.plot(history_iql['episode_lengths'],
               label='Independent Q-Learning', alpha=0.7)
        ax.plot(history_cql['episode_lengths'],
               label='Cooperative Q-Learning', alpha=0.7)
    
    ax.set_xlabel('Episode')
    ax.set_ylabel('Episode Length')
    ax.set_title('Training: Episode Lengths')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    ax = axes[1, 1]
    final_rewards_iql = history_iql['episode_rewards'][-100:]
    final_rewards_cql = history_cql['episode_rewards'][-100:]
    ax.hist(final_rewards_iql, bins=20, alpha=0.5, label='Independent Q-Learning')
    ax.hist(final_rewards_cql, bins=20, alpha=0.5, label='Cooperative Q-Learning')
    ax.set_xlabel('Total Reward')
    ax.set_ylabel('Frequency')
    ax.set_title('Final 100 Episodes: Reward Distribution')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(os.path.join(save_path, 'training_curves.png'), dpi=300)
    print(f"\nTraining curves saved to {os.path.join(save_path, 'training_curves.png')}")
    plt.show()

# %%
config = WarehouseConfig()
num_agents = 2  
env = MultiAgentWarehouseEnv(
    base_env_class=WarehouseRobotDetEnv,
    config=config,
    num_agents=num_agents,
    seed=42
)

print(f"Environment created with {num_agents} agents")
print(f"Grid size: {env.rows}x{env.cols}")
print(f"Joint action space size: {6**num_agents} (for Cooperative Q-Learning)")
# Out:
# Environment created with 2 agents
# Grid size: 6x6
# Joint action space size: 36 (for Cooperative Q-Learning)

# %%
num_episodes_iql = 15000  
num_episodes_cql = 20000 
max_steps_per_episode = 200
learning_rate = 0.1 
learning_rate_cql = 0.12  
discount_factor = 0.98 
epsilon_start = 1.0
epsilon_end = 0.01  
epsilon_decay = 0.0004  

num_episodes = num_episodes_iql  


print("=" * 60)
print(f"Number of agents: {num_agents}")
print(f"Training episodes - Independent: {num_episodes_iql}, Cooperative: {num_episodes_cql}")
print(f"Learning rates - Independent: {learning_rate}, Cooperative: {learning_rate_cql}")
print(f"Epsilon decay: exponential with rate {epsilon_decay}")
print("=" * 60)
# Out:
# ============================================================
# Number of agents: 2
# Training episodes - Independent: 15000, Cooperative: 20000
# Learning rates - Independent: 0.1, Cooperative: 0.12
# Epsilon decay: exponential with rate 0.0004
# ============================================================

# %%
print("\n" + "=" * 60)

history_iql, agent_iql = train_independent_qlearning(
    env=env,
    num_episodes=num_episodes,
    max_steps_per_episode=max_steps_per_episode,
    learning_rate=learning_rate,
    discount_factor=discount_factor,
    epsilon_start=epsilon_start,
    epsilon_end=epsilon_end,
    epsilon_decay=epsilon_decay
)
# Out:
# ============================================================
# Training Independent Q-Learning...
# Total episodes: 15000
# Episode 100/15000 | Avg Reward: -979.20 | Success Rate: 0.00% | Epsilon: 0.961
# Episode 200/15000 | Avg Reward: -888.29 | Success Rate: 4.00% | Epsilon: 0.923
# Episode 300/15000 | Avg Reward: -647.79 | Success Rate: 22.00% | Epsilon: 0.887
# Episode 400/15000 | Avg Reward: -461.94 | Success Rate: 49.00% | Epsilon: 0.852
# Episode 500/15000 | Avg Reward: -317.99 | Success Rate: 66.00% | Epsilon: 0.819
# Episode 600/15000 | Avg Reward: -249.32 | Success Rate: 72.00% | Epsilon: 0.787
# Episode 700/15000 | Avg Reward: -180.64 | Success Rate: 79.00% | Epsilon: 0.756
# Episode 800/15000 | Avg Reward: -215.13 | Success Rate: 57.00% | Epsilon: 0.726
# Episode 900/15000 | Avg Reward: -84.44 | Success Rate: 85.00% | Epsilon: 0.698
# Episode 1000/15000 | Avg Reward: -149.79 | Success Rate: 61.00% | Epsilon: 0.671
# Episode 1100/15000 | Avg Reward: -87.22 | Success Rate: 40.00% | Epsilon: 0.644
# Episode 1200/15000 | Avg Reward: -63.11 | Success Rate: 45.00% | Epsilon: 0.619
# Episode 1300/15000 | Avg Reward: -9.04 | Success Rate: 70.00% | Epsilon: 0.595
# Episode 1400/15000 | Avg Reward: -97.28 | Success Rate: 58.00% | Epsilon: 0.571
# Episode 1500/15000 | Avg Reward: 65.34 | Success Rate: 37.00% | Epsilon: 0.549
# Episode 1600/15000 | Avg Reward: 92.85 | Success Rate: 33.00% | Epsilon: 0.528
# Episode 1700/15000 | Avg Reward: 131.20 | Success Rate: 48.00% | Epsilon: 0.507
# Episode 1800/15000 | Avg Reward: -53.24 | Success Rate: 60.00% | Epsilon: 0.487
# Episode 1900/15000 | Avg Reward: 217.06 | Success Rate: 31.00% | Epsilon: 0.468
# Episode 2000/15000 | Avg Reward: 223.36 | Success Rate: 28.00% | Epsilon: 0.450
# Episode 2100/15000 | Avg Reward: 204.28 | Success Rate: 55.00% | Epsilon: 0.432
# Episode 2200/15000 | Avg Reward: -2.12 | Success Rate: 58.00% | Epsilon: 0.415
# Episode 2300/15000 | Avg Reward: 294.60 | Success Rate: 34.00% | Epsilon: 0.399
# Episode 2400/15000 | Avg Reward: 352.24 | Success Rate: 29.00% | Epsilon: 0.383
# Episode 2500/15000 | Avg Reward: 307.58 | Success Rate: 55.00% | Epsilon: 0.368
# Episode 2600/15000 | Avg Reward: 22.16 | Success Rate: 58.00% | Epsilon: 0.354
# Episode 2700/15000 | Avg Reward: 514.17 | Success Rate: 28.00% | Epsilon: 0.340
# Episode 2800/15000 | Avg Reward: 502.13 | Success Rate: 27.00% | Epsilon: 0.326
# Episode 2900/15000 | Avg Reward: 229.76 | Success Rate: 81.00% | Epsilon: 0.314
# Episode 3000/15000 | Avg Reward: 280.18 | Success Rate: 51.00% | Epsilon: 0.301
# Episode 3100/15000 | Avg Reward: 654.62 | Success Rate: 14.00% | Epsilon: 0.289
# Episode 3200/15000 | Avg Reward: 349.74 | Success Rate: 68.00% | Epsilon: 0.278
# Episode 3300/15000 | Avg Reward: 204.10 | Success Rate: 63.00% | Epsilon: 0.267
# Episode 3400/15000 | Avg Reward: 709.54 | Success Rate: 30.00% | Epsilon: 0.257
# Episode 3500/15000 | Avg Reward: 378.20 | Success Rate: 66.00% | Epsilon: 0.247
# Episode 3600/15000 | Avg Reward: 301.85 | Success Rate: 45.00% | Epsilon: 0.237
# Episode 3700/15000 | Avg Reward: 696.49 | Success Rate: 55.00% | Epsilon: 0.228
# Episode 3800/15000 | Avg Reward: 214.53 | Success Rate: 77.00% | Epsilon: 0.219
# Episode 3900/15000 | Avg Reward: 592.25 | Success Rate: 56.00% | Epsilon: 0.210
# Episode 4000/15000 | Avg Reward: 576.89 | Success Rate: 71.00% | Epsilon: 0.202
# Episode 4100/15000 | Avg Reward: 328.08 | Success Rate: 81.00% | Epsilon: 0.194
# Episode 4200/15000 | Avg Reward: 669.38 | Success Rate: 38.00% | Epsilon: 0.186
# Episode 4300/15000 | Avg Reward: 412.07 | Success Rate: 73.00% | Epsilon: 0.179
# Episode 4400/15000 | Avg Reward: 602.87 | Success Rate: 53.00% | Epsilon: 0.172
# Episode 4500/15000 | Avg Reward: 450.44 | Success Rate: 92.00% | Epsilon: 0.165
# Episode 4600/15000 | Avg Reward: 659.16 | Success Rate: 60.00% | Epsilon: 0.159
# Episode 4700/15000 | Avg Reward: 541.35 | Success Rate: 94.00% | Epsilon: 0.153
# Episode 4800/15000 | Avg Reward: 458.64 | Success Rate: 65.00% | Epsilon: 0.147
# Episode 4900/15000 | Avg Reward: 548.27 | Success Rate: 93.00% | Epsilon: 0.141
# Episode 5000/15000 | Avg Reward: 404.68 | Success Rate: 77.00% | Epsilon: 0.135
# Episode 5100/15000 | Avg Reward: 745.42 | Success Rate: 81.00% | Epsilon: 0.130
# Episode 5200/15000 | Avg Reward: 584.31 | Success Rate: 65.00% | Epsilon: 0.125
# Episode 5300/15000 | Avg Reward: 624.75 | Success Rate: 97.00% | Epsilon: 0.120
# Episode 5400/15000 | Avg Reward: 342.37 | Success Rate: 80.00% | Epsilon: 0.115
# Episode 5500/15000 | Avg Reward: 632.59 | Success Rate: 84.00% | Epsilon: 0.111
# Episode 5600/15000 | Avg Reward: 465.74 | Success Rate: 99.00% | Epsilon: 0.107
# Episode 5700/15000 | Avg Reward: 426.20 | Success Rate: 89.00% | Epsilon: 0.102
# Episode 5800/15000 | Avg Reward: 578.97 | Success Rate: 88.00% | Epsilon: 0.098
# Episode 5900/15000 | Avg Reward: 481.57 | Success Rate: 99.00% | Epsilon: 0.094
# Episode 6000/15000 | Avg Reward: 417.81 | Success Rate: 95.00% | Epsilon: 0.091
# Episode 6100/15000 | Avg Reward: 501.90 | Success Rate: 91.00% | Epsilon: 0.087
# Episode 6200/15000 | Avg Reward: 518.55 | Success Rate: 91.00% | Epsilon: 0.084
# Episode 6300/15000 | Avg Reward: 485.49 | Success Rate: 93.00% | Epsilon: 0.080
# Episode 6400/15000 | Avg Reward: 634.45 | Success Rate: 88.00% | Epsilon: 0.077
# Episode 6500/15000 | Avg Reward: 513.50 | Success Rate: 97.00% | Epsilon: 0.074
# Episode 6600/15000 | Avg Reward: 564.24 | Success Rate: 85.00% | Epsilon: 0.071
# Episode 6700/15000 | Avg Reward: 606.15 | Success Rate: 88.00% | Epsilon: 0.069
# Episode 6800/15000 | Avg Reward: 467.99 | Success Rate: 96.00% | Epsilon: 0.066
# Episode 6900/15000 | Avg Reward: 482.94 | Success Rate: 87.00% | Epsilon: 0.063
# Episode 7000/15000 | Avg Reward: 490.37 | Success Rate: 93.00% | Epsilon: 0.061
# Episode 7100/15000 | Avg Reward: 480.13 | Success Rate: 92.00% | Epsilon: 0.058
# Episode 7200/15000 | Avg Reward: 433.05 | Success Rate: 95.00% | Epsilon: 0.056
# Episode 7300/15000 | Avg Reward: 470.98 | Success Rate: 92.00% | Epsilon: 0.054
# Episode 7400/15000 | Avg Reward: 515.31 | Success Rate: 90.00% | Epsilon: 0.052
# Episode 7500/15000 | Avg Reward: 468.13 | Success Rate: 98.00% | Epsilon: 0.050
# Episode 7600/15000 | Avg Reward: 548.84 | Success Rate: 93.00% | Epsilon: 0.048
# Episode 7700/15000 | Avg Reward: 478.01 | Success Rate: 99.00% | Epsilon: 0.046
# Episode 7800/15000 | Avg Reward: 441.33 | Success Rate: 96.00% | Epsilon: 0.044
# Episode 7900/15000 | Avg Reward: 547.05 | Success Rate: 91.00% | Epsilon: 0.042
# Episode 8000/15000 | Avg Reward: 460.86 | Success Rate: 96.00% | Epsilon: 0.041
# Episode 8100/15000 | Avg Reward: 502.93 | Success Rate: 93.00% | Epsilon: 0.039
# Episode 8200/15000 | Avg Reward: 454.56 | Success Rate: 97.00% | Epsilon: 0.038
# Episode 8300/15000 | Avg Reward: 450.51 | Success Rate: 97.00% | Epsilon: 0.036
# Episode 8400/15000 | Avg Reward: 465.34 | Success Rate: 95.00% | Epsilon: 0.035
# Episode 8500/15000 | Avg Reward: 467.34 | Success Rate: 98.00% | Epsilon: 0.033
# Episode 8600/15000 | Avg Reward: 465.80 | Success Rate: 96.00% | Epsilon: 0.032
# Episode 8700/15000 | Avg Reward: 499.43 | Success Rate: 95.00% | Epsilon: 0.031
# Episode 8800/15000 | Avg Reward: 438.49 | Success Rate: 100.00% | Epsilon: 0.030
# Episode 8900/15000 | Avg Reward: 474.97 | Success Rate: 95.00% | Epsilon: 0.028
# Episode 9000/15000 | Avg Reward: 430.74 | Success Rate: 99.00% | Epsilon: 0.027
# Episode 9100/15000 | Avg Reward: 494.27 | Success Rate: 95.00% | Epsilon: 0.026
# Episode 9200/15000 | Avg Reward: 446.32 | Success Rate: 96.00% | Epsilon: 0.025
# Episode 9300/15000 | Avg Reward: 470.59 | Success Rate: 94.00% | Epsilon: 0.024
# Episode 9400/15000 | Avg Reward: 517.52 | Success Rate: 93.00% | Epsilon: 0.023
# Episode 9500/15000 | Avg Reward: 428.28 | Success Rate: 98.00% | Epsilon: 0.022
# Episode 9600/15000 | Avg Reward: 469.31 | Success Rate: 95.00% | Epsilon: 0.022
# Episode 9700/15000 | Avg Reward: 472.88 | Success Rate: 98.00% | Epsilon: 0.021
# Episode 9800/15000 | Avg Reward: 452.01 | Success Rate: 98.00% | Epsilon: 0.020
# Episode 9900/15000 | Avg Reward: 448.21 | Success Rate: 99.00% | Epsilon: 0.019
# Episode 10000/15000 | Avg Reward: 478.75 | Success Rate: 92.00% | Epsilon: 0.018
# Episode 10100/15000 | Avg Reward: 515.23 | Success Rate: 88.00% | Epsilon: 0.018
# Episode 10200/15000 | Avg Reward: 487.01 | Success Rate: 95.00% | Epsilon: 0.017
# Episode 10300/15000 | Avg Reward: 451.58 | Success Rate: 97.00% | Epsilon: 0.016
# Episode 10400/15000 | Avg Reward: 460.47 | Success Rate: 94.00% | Epsilon: 0.016
# Episode 10500/15000 | Avg Reward: 442.00 | Success Rate: 98.00% | Epsilon: 0.015
# Episode 10600/15000 | Avg Reward: 462.10 | Success Rate: 95.00% | Epsilon: 0.014
# Episode 10700/15000 | Avg Reward: 467.20 | Success Rate: 97.00% | Epsilon: 0.014
# Episode 10800/15000 | Avg Reward: 440.05 | Success Rate: 99.00% | Epsilon: 0.013
# Episode 10900/15000 | Avg Reward: 431.46 | Success Rate: 100.00% | Epsilon: 0.013
# Episode 11000/15000 | Avg Reward: 450.99 | Success Rate: 99.00% | Epsilon: 0.012
# Episode 11100/15000 | Avg Reward: 436.75 | Success Rate: 99.00% | Epsilon: 0.012
# Episode 11200/15000 | Avg Reward: 434.45 | Success Rate: 97.00% | Epsilon: 0.011
# Episode 11300/15000 | Avg Reward: 551.66 | Success Rate: 87.00% | Epsilon: 0.011
# Episode 11400/15000 | Avg Reward: 429.40 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 11500/15000 | Avg Reward: 430.13 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 11600/15000 | Avg Reward: 443.26 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 11700/15000 | Avg Reward: 439.90 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 11800/15000 | Avg Reward: 445.65 | Success Rate: 99.00% | Epsilon: 0.010
# Episode 11900/15000 | Avg Reward: 457.14 | Success Rate: 96.00% | Epsilon: 0.010
# Episode 12000/15000 | Avg Reward: 428.61 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12100/15000 | Avg Reward: 445.31 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12200/15000 | Avg Reward: 430.76 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12300/15000 | Avg Reward: 428.24 | Success Rate: 98.00% | Epsilon: 0.010
# Episode 12400/15000 | Avg Reward: 475.34 | Success Rate: 94.00% | Epsilon: 0.010
# Episode 12500/15000 | Avg Reward: 509.41 | Success Rate: 90.00% | Epsilon: 0.010
# Episode 12600/15000 | Avg Reward: 471.92 | Success Rate: 93.00% | Epsilon: 0.010
# Episode 12700/15000 | Avg Reward: 436.72 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12800/15000 | Avg Reward: 440.42 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12900/15000 | Avg Reward: 437.07 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13000/15000 | Avg Reward: 452.40 | Success Rate: 99.00% | Epsilon: 0.010
# Episode 13100/15000 | Avg Reward: 471.84 | Success Rate: 96.00% | Epsilon: 0.010
# Episode 13200/15000 | Avg Reward: 448.84 | Success Rate: 98.00% | Epsilon: 0.010
# Episode 13300/15000 | Avg Reward: 459.91 | Success Rate: 96.00% | Epsilon: 0.010
# Episode 13400/15000 | Avg Reward: 439.50 | Success Rate: 97.00% | Epsilon: 0.010
# Episode 13500/15000 | Avg Reward: 427.14 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13600/15000 | Avg Reward: 453.99 | Success Rate: 96.00% | Epsilon: 0.010
# Episode 13700/15000 | Avg Reward: 488.97 | Success Rate: 94.00% | Epsilon: 0.010
# Episode 13800/15000 | Avg Reward: 428.04 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13900/15000 | Avg Reward: 439.34 | Success Rate: 97.00% | Epsilon: 0.010
# Episode 14000/15000 | Avg Reward: 458.35 | Success Rate: 99.00% | Epsilon: 0.010
# Episode 14100/15000 | Avg Reward: 427.32 | Success Rate: 97.00% | Epsilon: 0.010
# Episode 14200/15000 | Avg Reward: 446.07 | Success Rate: 98.00% | Epsilon: 0.010
# Episode 14300/15000 | Avg Reward: 432.64 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 14400/15000 | Avg Reward: 426.74 | Success Rate: 99.00% | Epsilon: 0.010
# Episode 14500/15000 | Avg Reward: 430.79 | Success Rate: 97.00% | Epsilon: 0.010
# Episode 14600/15000 | Avg Reward: 436.36 | Success Rate: 98.00% | Epsilon: 0.010
# Episode 14700/15000 | Avg Reward: 484.99 | Success Rate: 94.00% | Epsilon: 0.010
# Episode 14800/15000 | Avg Reward: 428.42 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 14900/15000 | Avg Reward: 419.96 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 15000/15000 | Avg Reward: 421.76 | Success Rate: 99.00% | Epsilon: 0.010

# %%
print("\n" + "=" * 60)
print("Training Cooperative Q-Learning")


history_cql, agent_cql = train_cooperative_qlearning(
        env=env,
        num_episodes=num_episodes_cql, 
        max_steps_per_episode=max_steps_per_episode,
        learning_rate=learning_rate_cql,  
        discount_factor=discount_factor,
        epsilon_start=epsilon_start,
        epsilon_end=epsilon_end,
        epsilon_decay=epsilon_decay
        )
# Out:
# ============================================================
# Training Cooperative Q-Learning
# Training Cooperative Q-Learning...
# Total episodes: 20000
# Episode 100/20000 | Avg Reward: -1028.15 | Success Rate: 0.00% | Epsilon: 0.961
# Episode 200/20000 | Avg Reward: -1030.80 | Success Rate: 0.00% | Epsilon: 0.923
# Episode 300/20000 | Avg Reward: -1013.65 | Success Rate: 0.00% | Epsilon: 0.887
# Episode 400/20000 | Avg Reward: -991.80 | Success Rate: 0.00% | Epsilon: 0.852
# Episode 500/20000 | Avg Reward: -967.95 | Success Rate: 0.00% | Epsilon: 0.819
# Episode 600/20000 | Avg Reward: -939.95 | Success Rate: 0.00% | Epsilon: 0.787
# Episode 700/20000 | Avg Reward: -899.06 | Success Rate: 1.00% | Epsilon: 0.756
# Episode 800/20000 | Avg Reward: -836.08 | Success Rate: 1.00% | Epsilon: 0.726
# Episode 900/20000 | Avg Reward: -715.16 | Success Rate: 5.00% | Epsilon: 0.698
# Episode 1000/20000 | Avg Reward: -661.15 | Success Rate: 6.00% | Epsilon: 0.671
# Episode 1100/20000 | Avg Reward: -548.26 | Success Rate: 7.00% | Epsilon: 0.644
# Episode 1200/20000 | Avg Reward: -335.78 | Success Rate: 26.00% | Epsilon: 0.619
# Episode 1300/20000 | Avg Reward: -107.85 | Success Rate: 41.00% | Epsilon: 0.595
# Episode 1400/20000 | Avg Reward: 233.69 | Success Rate: 66.00% | Epsilon: 0.571
# Episode 1500/20000 | Avg Reward: 390.46 | Success Rate: 75.00% | Epsilon: 0.549
# Episode 1600/20000 | Avg Reward: 473.96 | Success Rate: 79.00% | Epsilon: 0.528
# Episode 1700/20000 | Avg Reward: 653.43 | Success Rate: 95.00% | Epsilon: 0.507
# Episode 1800/20000 | Avg Reward: 703.63 | Success Rate: 97.00% | Epsilon: 0.487
# Episode 1900/20000 | Avg Reward: 730.28 | Success Rate: 100.00% | Epsilon: 0.468
# Episode 2000/20000 | Avg Reward: 745.63 | Success Rate: 100.00% | Epsilon: 0.450
# Episode 2100/20000 | Avg Reward: 777.24 | Success Rate: 100.00% | Epsilon: 0.432
# Episode 2200/20000 | Avg Reward: 792.47 | Success Rate: 100.00% | Epsilon: 0.415
# Episode 2300/20000 | Avg Reward: 794.43 | Success Rate: 100.00% | Epsilon: 0.399
# Episode 2400/20000 | Avg Reward: 797.15 | Success Rate: 100.00% | Epsilon: 0.383
# Episode 2500/20000 | Avg Reward: 812.84 | Success Rate: 100.00% | Epsilon: 0.368
# Episode 2600/20000 | Avg Reward: 817.81 | Success Rate: 100.00% | Epsilon: 0.354
# Episode 2700/20000 | Avg Reward: 829.82 | Success Rate: 100.00% | Epsilon: 0.340
# Episode 2800/20000 | Avg Reward: 834.57 | Success Rate: 100.00% | Epsilon: 0.326
# Episode 2900/20000 | Avg Reward: 834.80 | Success Rate: 100.00% | Epsilon: 0.314
# Episode 3000/20000 | Avg Reward: 837.63 | Success Rate: 100.00% | Epsilon: 0.301
# Episode 3100/20000 | Avg Reward: 847.19 | Success Rate: 100.00% | Epsilon: 0.289
# Episode 3200/20000 | Avg Reward: 852.17 | Success Rate: 100.00% | Epsilon: 0.278
# Episode 3300/20000 | Avg Reward: 849.52 | Success Rate: 100.00% | Epsilon: 0.267
# Episode 3400/20000 | Avg Reward: 856.97 | Success Rate: 100.00% | Epsilon: 0.257
# Episode 3500/20000 | Avg Reward: 861.93 | Success Rate: 100.00% | Epsilon: 0.247
# Episode 3600/20000 | Avg Reward: 863.59 | Success Rate: 100.00% | Epsilon: 0.237
# Episode 3700/20000 | Avg Reward: 865.96 | Success Rate: 100.00% | Epsilon: 0.228
# Episode 3800/20000 | Avg Reward: 873.53 | Success Rate: 100.00% | Epsilon: 0.219
# Episode 3900/20000 | Avg Reward: 872.76 | Success Rate: 100.00% | Epsilon: 0.210
# Episode 4000/20000 | Avg Reward: 877.19 | Success Rate: 100.00% | Epsilon: 0.202
# Episode 4100/20000 | Avg Reward: 878.60 | Success Rate: 100.00% | Epsilon: 0.194
# Episode 4200/20000 | Avg Reward: 878.83 | Success Rate: 100.00% | Epsilon: 0.186
# Episode 4300/20000 | Avg Reward: 877.69 | Success Rate: 100.00% | Epsilon: 0.179
# Episode 4400/20000 | Avg Reward: 885.71 | Success Rate: 100.00% | Epsilon: 0.172
# Episode 4500/20000 | Avg Reward: 885.49 | Success Rate: 100.00% | Epsilon: 0.165
# Episode 4600/20000 | Avg Reward: 891.61 | Success Rate: 100.00% | Epsilon: 0.159
# Episode 4700/20000 | Avg Reward: 891.37 | Success Rate: 100.00% | Epsilon: 0.153
# Episode 4800/20000 | Avg Reward: 890.63 | Success Rate: 100.00% | Epsilon: 0.147
# Episode 4900/20000 | Avg Reward: 891.41 | Success Rate: 100.00% | Epsilon: 0.141
# Episode 5000/20000 | Avg Reward: 897.41 | Success Rate: 100.00% | Epsilon: 0.135
# Episode 5100/20000 | Avg Reward: 896.14 | Success Rate: 100.00% | Epsilon: 0.130
# Episode 5200/20000 | Avg Reward: 895.71 | Success Rate: 100.00% | Epsilon: 0.125
# Episode 5300/20000 | Avg Reward: 894.20 | Success Rate: 100.00% | Epsilon: 0.120
# Episode 5400/20000 | Avg Reward: 898.18 | Success Rate: 100.00% | Epsilon: 0.115
# Episode 5500/20000 | Avg Reward: 894.86 | Success Rate: 100.00% | Epsilon: 0.111
# Episode 5600/20000 | Avg Reward: 896.15 | Success Rate: 100.00% | Epsilon: 0.107
# Episode 5700/20000 | Avg Reward: 899.19 | Success Rate: 100.00% | Epsilon: 0.102
# Episode 5800/20000 | Avg Reward: 897.88 | Success Rate: 100.00% | Epsilon: 0.098
# Episode 5900/20000 | Avg Reward: 902.86 | Success Rate: 100.00% | Epsilon: 0.094
# Episode 6000/20000 | Avg Reward: 898.41 | Success Rate: 100.00% | Epsilon: 0.091
# Episode 6100/20000 | Avg Reward: 901.18 | Success Rate: 100.00% | Epsilon: 0.087
# Episode 6200/20000 | Avg Reward: 900.22 | Success Rate: 100.00% | Epsilon: 0.084
# Episode 6300/20000 | Avg Reward: 906.88 | Success Rate: 100.00% | Epsilon: 0.080
# Episode 6400/20000 | Avg Reward: 902.95 | Success Rate: 100.00% | Epsilon: 0.077
# Episode 6500/20000 | Avg Reward: 903.29 | Success Rate: 100.00% | Epsilon: 0.074
# Episode 6600/20000 | Avg Reward: 909.53 | Success Rate: 100.00% | Epsilon: 0.071
# Episode 6700/20000 | Avg Reward: 904.47 | Success Rate: 100.00% | Epsilon: 0.069
# Episode 6800/20000 | Avg Reward: 903.94 | Success Rate: 100.00% | Epsilon: 0.066
# Episode 6900/20000 | Avg Reward: 905.92 | Success Rate: 100.00% | Epsilon: 0.063
# Episode 7000/20000 | Avg Reward: 905.28 | Success Rate: 100.00% | Epsilon: 0.061
# Episode 7100/20000 | Avg Reward: 905.82 | Success Rate: 100.00% | Epsilon: 0.058
# Episode 7200/20000 | Avg Reward: 905.16 | Success Rate: 100.00% | Epsilon: 0.056
# Episode 7300/20000 | Avg Reward: 905.53 | Success Rate: 100.00% | Epsilon: 0.054
# Episode 7400/20000 | Avg Reward: 911.14 | Success Rate: 100.00% | Epsilon: 0.052
# Episode 7500/20000 | Avg Reward: 910.27 | Success Rate: 100.00% | Epsilon: 0.050
# Episode 7600/20000 | Avg Reward: 907.54 | Success Rate: 100.00% | Epsilon: 0.048
# Episode 7700/20000 | Avg Reward: 909.37 | Success Rate: 100.00% | Epsilon: 0.046
# Episode 7800/20000 | Avg Reward: 911.86 | Success Rate: 100.00% | Epsilon: 0.044
# Episode 7900/20000 | Avg Reward: 906.17 | Success Rate: 100.00% | Epsilon: 0.042
# Episode 8000/20000 | Avg Reward: 910.43 | Success Rate: 100.00% | Epsilon: 0.041
# Episode 8100/20000 | Avg Reward: 909.52 | Success Rate: 100.00% | Epsilon: 0.039
# Episode 8200/20000 | Avg Reward: 910.02 | Success Rate: 100.00% | Epsilon: 0.038
# Episode 8300/20000 | Avg Reward: 911.27 | Success Rate: 100.00% | Epsilon: 0.036
# Episode 8400/20000 | Avg Reward: 914.54 | Success Rate: 100.00% | Epsilon: 0.035
# Episode 8500/20000 | Avg Reward: 910.31 | Success Rate: 100.00% | Epsilon: 0.033
# Episode 8600/20000 | Avg Reward: 909.75 | Success Rate: 100.00% | Epsilon: 0.032
# Episode 8700/20000 | Avg Reward: 910.91 | Success Rate: 100.00% | Epsilon: 0.031
# Episode 8800/20000 | Avg Reward: 911.68 | Success Rate: 100.00% | Epsilon: 0.030
# Episode 8900/20000 | Avg Reward: 914.58 | Success Rate: 100.00% | Epsilon: 0.028
# Episode 9000/20000 | Avg Reward: 911.18 | Success Rate: 100.00% | Epsilon: 0.027
# Episode 9100/20000 | Avg Reward: 911.22 | Success Rate: 100.00% | Epsilon: 0.026
# Episode 9200/20000 | Avg Reward: 910.67 | Success Rate: 100.00% | Epsilon: 0.025
# Episode 9300/20000 | Avg Reward: 912.23 | Success Rate: 100.00% | Epsilon: 0.024
# Episode 9400/20000 | Avg Reward: 910.77 | Success Rate: 100.00% | Epsilon: 0.023
# Episode 9500/20000 | Avg Reward: 913.01 | Success Rate: 100.00% | Epsilon: 0.022
# Episode 9600/20000 | Avg Reward: 912.37 | Success Rate: 100.00% | Epsilon: 0.022
# Episode 9700/20000 | Avg Reward: 911.97 | Success Rate: 100.00% | Epsilon: 0.021
# Episode 9800/20000 | Avg Reward: 912.09 | Success Rate: 100.00% | Epsilon: 0.020
# Episode 9900/20000 | Avg Reward: 910.36 | Success Rate: 100.00% | Epsilon: 0.019
# Episode 10000/20000 | Avg Reward: 911.54 | Success Rate: 100.00% | Epsilon: 0.018
# Episode 10100/20000 | Avg Reward: 912.90 | Success Rate: 100.00% | Epsilon: 0.018
# Episode 10200/20000 | Avg Reward: 911.96 | Success Rate: 100.00% | Epsilon: 0.017
# Episode 10300/20000 | Avg Reward: 915.08 | Success Rate: 100.00% | Epsilon: 0.016
# Episode 10400/20000 | Avg Reward: 911.34 | Success Rate: 100.00% | Epsilon: 0.016
# Episode 10500/20000 | Avg Reward: 912.52 | Success Rate: 100.00% | Epsilon: 0.015
# Episode 10600/20000 | Avg Reward: 914.58 | Success Rate: 100.00% | Epsilon: 0.014
# Episode 10700/20000 | Avg Reward: 913.02 | Success Rate: 100.00% | Epsilon: 0.014
# Episode 10800/20000 | Avg Reward: 914.09 | Success Rate: 100.00% | Epsilon: 0.013
# Episode 10900/20000 | Avg Reward: 912.41 | Success Rate: 100.00% | Epsilon: 0.013
# Episode 11000/20000 | Avg Reward: 913.57 | Success Rate: 100.00% | Epsilon: 0.012
# Episode 11100/20000 | Avg Reward: 913.33 | Success Rate: 100.00% | Epsilon: 0.012
# Episode 11200/20000 | Avg Reward: 915.23 | Success Rate: 100.00% | Epsilon: 0.011
# Episode 11300/20000 | Avg Reward: 912.96 | Success Rate: 100.00% | Epsilon: 0.011
# Episode 11400/20000 | Avg Reward: 915.03 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 11500/20000 | Avg Reward: 915.28 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 11600/20000 | Avg Reward: 914.24 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 11700/20000 | Avg Reward: 913.55 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 11800/20000 | Avg Reward: 913.60 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 11900/20000 | Avg Reward: 915.85 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12000/20000 | Avg Reward: 914.44 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12100/20000 | Avg Reward: 914.79 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12200/20000 | Avg Reward: 915.04 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12300/20000 | Avg Reward: 913.29 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12400/20000 | Avg Reward: 914.73 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12500/20000 | Avg Reward: 914.87 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12600/20000 | Avg Reward: 914.31 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12700/20000 | Avg Reward: 914.50 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12800/20000 | Avg Reward: 914.24 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 12900/20000 | Avg Reward: 916.98 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13000/20000 | Avg Reward: 913.83 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13100/20000 | Avg Reward: 914.02 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13200/20000 | Avg Reward: 916.75 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13300/20000 | Avg Reward: 913.81 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13400/20000 | Avg Reward: 915.83 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13500/20000 | Avg Reward: 911.94 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13600/20000 | Avg Reward: 916.19 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13700/20000 | Avg Reward: 915.04 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13800/20000 | Avg Reward: 912.58 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 13900/20000 | Avg Reward: 915.06 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 14000/20000 | Avg Reward: 914.53 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 14100/20000 | Avg Reward: 912.56 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 14200/20000 | Avg Reward: 914.19 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 14300/20000 | Avg Reward: 914.84 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 14400/20000 | Avg Reward: 917.53 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 14500/20000 | Avg Reward: 913.32 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 14600/20000 | Avg Reward: 914.28 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 14700/20000 | Avg Reward: 916.75 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 14800/20000 | Avg Reward: 915.05 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 14900/20000 | Avg Reward: 912.27 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 15000/20000 | Avg Reward: 914.13 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 15100/20000 | Avg Reward: 914.15 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 15200/20000 | Avg Reward: 915.15 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 15300/20000 | Avg Reward: 913.81 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 15400/20000 | Avg Reward: 912.96 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 15500/20000 | Avg Reward: 912.01 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 15600/20000 | Avg Reward: 913.19 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 15700/20000 | Avg Reward: 913.28 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 15800/20000 | Avg Reward: 913.80 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 15900/20000 | Avg Reward: 913.92 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 16000/20000 | Avg Reward: 913.47 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 16100/20000 | Avg Reward: 914.47 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 16200/20000 | Avg Reward: 914.37 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 16300/20000 | Avg Reward: 914.73 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 16400/20000 | Avg Reward: 914.53 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 16500/20000 | Avg Reward: 915.76 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 16600/20000 | Avg Reward: 913.73 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 16700/20000 | Avg Reward: 915.38 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 16800/20000 | Avg Reward: 913.37 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 16900/20000 | Avg Reward: 915.53 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 17000/20000 | Avg Reward: 914.77 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 17100/20000 | Avg Reward: 914.12 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 17200/20000 | Avg Reward: 913.63 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 17300/20000 | Avg Reward: 915.12 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 17400/20000 | Avg Reward: 912.61 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 17500/20000 | Avg Reward: 912.92 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 17600/20000 | Avg Reward: 913.92 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 17700/20000 | Avg Reward: 914.33 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 17800/20000 | Avg Reward: 913.58 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 17900/20000 | Avg Reward: 914.87 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 18000/20000 | Avg Reward: 913.28 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 18100/20000 | Avg Reward: 916.72 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 18200/20000 | Avg Reward: 914.18 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 18300/20000 | Avg Reward: 914.62 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 18400/20000 | Avg Reward: 913.10 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 18500/20000 | Avg Reward: 914.67 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 18600/20000 | Avg Reward: 913.11 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 18700/20000 | Avg Reward: 913.69 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 18800/20000 | Avg Reward: 916.30 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 18900/20000 | Avg Reward: 916.90 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 19000/20000 | Avg Reward: 915.17 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 19100/20000 | Avg Reward: 914.67 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 19200/20000 | Avg Reward: 913.08 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 19300/20000 | Avg Reward: 914.40 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 19400/20000 | Avg Reward: 915.58 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 19500/20000 | Avg Reward: 912.50 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 19600/20000 | Avg Reward: 915.87 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 19700/20000 | Avg Reward: 914.79 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 19800/20000 | Avg Reward: 916.33 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 19900/20000 | Avg Reward: 917.78 | Success Rate: 100.00% | Epsilon: 0.010
# Episode 20000/20000 | Avg Reward: 913.72 | Success Rate: 100.00% | Epsilon: 0.010

# %%
eval_iql = evaluate_agent(env, agent_iql, method='independent', num_episodes=100, seed=42)
eval_cql = evaluate_agent(env, agent_cql, method='cooperative', num_episodes=100, seed=42)
# Out:
# Evaluating independent agent...
# Mean Reward: 384.68 ± 163.38
# Mean Length: 37.89 ± 54.15
# Success Rate: 90.00%
#
# Evaluating cooperative agent...
# Mean Reward: 414.78 ± 11.31
# Mean Length: 34.51 ± 7.07
# Success Rate: 100.00%

# %%
os.makedirs('results', exist_ok=True)
plot_training_curves(history_iql, history_cql, save_path='results')
# Out:
# Training curves saved to results\training_curves.png

# %%
import pickle
results = {
    'independent': {
        'training_history': history_iql,
        'evaluation': eval_iql
    },
    'cooperative': {
        'training_history': history_cql,
        'evaluation': eval_cql
    }
}

with open('results/experiment_results.pkl', 'wb') as f:
    pickle.dump(results, f)

print("Results saved to results/experiment_results.pkl")
# Out:
# Results saved to results/experiment_results.pkl

# %%
print(f"\nIndependent Q-Learning:")
print(f"  Final Mean Reward: {eval_iql['mean_reward']:.2f} ± {eval_iql['std_reward']:.2f}")
print(f"  Success Rate: {eval_iql['success_rate']:.2%}")
print(f"  Mean Episode Length: {eval_iql['mean_length']:.2f} ± {eval_iql['std_length']:.2f}")

print(f"\nCooperative Q-Learning:")
print(f"  Final Mean Reward: {eval_cql['mean_reward']:.2f} ± {eval_cql['std_reward']:.2f}")
print(f"  Success Rate: {eval_cql['success_rate']:.2%}")
print(f"  Mean Episode Length: {eval_cql['mean_length']:.2f} ± {eval_cql['std_length']:.2f}")
env.close()
# Out:
# Independent Q-Learning:
#   Final Mean Reward: 384.68 ± 163.38
#   Success Rate: 90.00%
#   Mean Episode Length: 37.89 ± 54.15
#
# Cooperative Q-Learning:
#   Final Mean Reward: 414.78 ± 11.31
#   Success Rate: 100.00%
#   Mean Episode Length: 34.51 ± 7.07
